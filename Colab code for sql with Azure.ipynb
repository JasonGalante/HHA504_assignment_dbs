# %%
# !pip install sqlalchemy pymysql pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse

# %%
df = pd.read_csv('Electoral_College.csv')
df
# Out:
#       Year    State  Votes
# 0     1788  Alabama    NaN
# 1     1792  Alabama    NaN
# 2     1796  Alabama    NaN
# 3     1800  Alabama    NaN
# 4     1804  Alabama    NaN
# ...    ...      ...    ...
# 3004  2004  Wyoming    3.0
# 3005  2008  Wyoming    3.0
# 3006  2012  Wyoming    3.0
# 3007  2016  Wyoming    3.0
# 3008  2020  Wyoming    3.0
#
# [3009 rows x 3 columns]

# %%
username = 'jmg'
password = 'Alphast@r2733'
host = 'jasonhw.mysql.database.azure.com'
port = 3306
database = 'test'

# URL encode the password to handle special characters
encoded_password = urllib.parse.quote_plus(password)

# Update the connection string with the encoded password
connection_string = f'mysql+pymysql://{username}:{encoded_password}@{host}:{port}/{database}'

# Create the SQLAlchemy engine
engine = create_engine(connection_string)

# Now you can use the engine to interact with the database

# %%
df.to_sql('Year',engine, if_exists='replace')
# Out:
# <ipython-input-16-34cd1540a97a>:1: UserWarning: The provided table name 'Year' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql('Year',engine, if_exists='replace')
# 3009

# %%
query = '''
SELECT DISTINCT Year
FROM Year
Limit 50
'''

# %%
test_return = pd.read_sql(query, engine)
test_return
# Out:
#     Year
# 0   1788
# 1   1792
# 2   1796
# 3   1800
# 4   1804
# 5   1808
# 6   1812
# 7   1816
# 8   1820
# 9   1824
# 10  1828
# 11  1832
# 12  1836
# 13  1840
# 14  1844
# 15  1848
# 16  1852
# 17  1856
# 18  1860
# 19  1864
# 20  1868
# 21  1872
# 22  1876
# 23  1880
# 24  1884
# 25  1888
# 26  1892
# 27  1896
# 28  1900
# 29  1904
# 30  1908
# 31  1912
# 32  1916
# 33  1920
# 34  1924
# 35  1928
# 36  1932
# 37  1936
# 38  1940
# 39  1944
# 40  1948
# 41  1952
# 42  1956
# 43  1960
# 44  1964
# 45  1968
# 46  1972
# 47  1976
# 48  1980
# 49  1984
